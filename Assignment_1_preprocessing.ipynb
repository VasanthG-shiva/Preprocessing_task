# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("programminglanguage.csv")
print(df.head())
# Out:
#      Year                 Name Chief developer, company  \
# 0     NaN     Jacquard machine    Joseph Marie Jacquard
# 1     NaN     Jacquard machine    Joseph Marie Jacquard
# 2  1879.0                                 Gottlob Frege
# 3  1944.0  ENIAC coding system                      NaN
# 4  1948.0           Plankalkül
#
#            Predecessor(s)
# 0  none (unique language)
# 1  none (unique language)
# 2  none (unique language)
# 3  none (unique language)
# 4  none (unique language)

# %% [markdown]
# First 5 rows

# %%
print(df.columns)
# Out:
# Index(['Year', 'Name', 'Chief developer, company', 'Predecessor(s)'], dtype='object')

# %% [markdown]
# columns names

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      393 non-null    float64
#  1   Name                      395 non-null    object
#  2   Chief developer, company  383 non-null    object
#  3   Predecessor(s)            357 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 12.5+ KB
# None

# %% [markdown]
# dataset info

# %%
print(df.describe())
# Out:
#               Year
# count   393.000000
# mean   1983.544529
# std      19.352890
# min    1879.000000
# 25%    1968.000000
# 50%    1985.000000
# 75%    1998.000000
# max    2022.000000

# %% [markdown]
# numeric column descibe

# %%
print(df.shape)
# Out:
# (395, 4)

# %%
dataset rows and columns

# %%
print(df.duplicated().sum())
# Out:
# 1

# %%
df = df.drop_duplicates().reset_index(drop=True)
print(df.shape)
# Out:
# (394, 4)

# %% [markdown]
# duplicate was droped

# %%
for col in numeric_columns:
    df[col]= pd.to_numeric(df[col],errors='coerce')

print()

# %%
numeric_columns = df.select_dtypes(include=["int64","float64"]).columns.tolist()
categorical_columns = df.select_dtypes(include=["O"]).columns.tolist()
print("numeric_columns:",numeric_columns)
print("categorical_columns:", catagorical_columns)
# Out:
# numeric_columns: ['Year']
# categorical_columns: ['Name', 'Chief developer, company', 'Predecessor(s)']

# %%
for col in numeric_columns:
    df[col] =pd.to_numeric(df[col],errors='coerce')

print(df)
# Out:
#        Year                    Name  \
# 0       NaN        Jacquard machine
# 1    1879.0
# 2    1944.0     ENIAC coding system
# 3    1948.0              Plankalkül
# 4    1948.0  ARC/Birkbeck Assembler
# ..      ...                     ...
# 389  2018.0            Fortran 2018
# 390  2019.0                  Bosque
# 391  2020.0                   C++20
# 392  2021.0      Microsoft Power Fx
# 393  2022.0                  Carbon
#
#                               Chief developer, company  \
# 0                                Joseph Marie Jacquard
# 1                                        Gottlob Frege
# 2                                                  NaN
# 3
# 4                                       Kathleen Booth
# ..                                                 ...
# 389                   ISO/IEC JTC1/SC22/WG5 N2150:2018
# 390                             Mark Marron, Microsoft
# 391                             C++ ISO/IEC 14882:2020
# ...

# %% [markdown]
# numeric columns to convert orginal numeric columns because some dataset have numeric column have string value

# %%
print(df.isnull().sum())
# Out:
# Year                         1
# Name                         0
# Chief developer, company    12
# Predecessor(s)              38
# dtype: int64

# %%
print(numeric_columns)
# Out:
# ['Year']

# %%
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].median())
df[categorical_columns]=df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])
print(df[categorical_columns].mode())
print("____")
print(df.isnull().sum())
# Out:
#          Name Chief developer, company          Predecessor(s)
# 0  Short Code                      IBM  none (unique language)
# ____
# Year                        0
# Name                        0
# Chief developer, company    0
# Predecessor(s)              0
# dtype: int64

# %% [markdown]
# categorical columns and numeric columns remove null values

# %%
preprocessor = ColumnTransformer([
    ('category',OneHotEncoder(handle_unknown='ignore'),categorical_columns)],
                                 remainder='passthrough')
encode_columns = preprocessor.fit_transform(df)
print(encode_columns)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1576 stored elements and shape (394, 983)>
#   Coords	Values
#   (0, 192)	1.0
#   (0, 585)	1.0
#   (0, 978)	1.0
#   (0, 982)	1985.0
#   (1, 0)	1.0
#   (1, 529)	1.0
#   (1, 978)	1.0
#   (1, 982)	1879.0
#   (2, 115)	1.0
#   (2, 549)	1.0
#   (2, 978)	1.0
#   (2, 982)	1944.0
#   (3, 281)	1.0
#   (3, 393)	1.0
#   (3, 978)	1.0
#   (3, 982)	1948.0
#   (4, 18)	1.0
#   (4, 593)	1.0
#   (4, 978)	1.0
#   (4, 982)	1948.0
#   (5, 114)	1.0
#   (5, 497)	1.0
#   (5, 811)	1.0
#   (5, 982)	1949.0
#   (6, 337)	1.0
#   :	:
#   (387, 982)	2017.0
#   (388, 67)	1.0
#   (388, 552)	1.0
#   (388, 792)	1.0
#   (388, 982)	2018.0
#   (389, 140)	1.0
#   (389, 553)	1.0
#   (389, 837)	1.0
#   (389, 982)	2018.0
#   (390, 54)	1.0
#   (390, 610)	1.0
#   (390, 870)	1.0
#   (390, 982)	2019.0
#   (391, 65)	1.0
#   (391, 462)	1.0
#   (391, 782)	1.0
#   (391, 982)	2020.0
#   (392, 235)	1.0
#   (392, 706)	1.0
#   (392, 816)	1.0
#   (392, 982)	2021.0
# ...

# %%
std_scaler = StandardScaler()
df[numeric_columns]=std_scaler.fit_transform(df[numeric_columns])

# %%
x = df.drop("Year",axis=1)
y = df["Year"]

print(x)
print(y)
# Out:
#                        Name  \
# 0          Jacquard machine
# 1
# 2       ENIAC coding system
# 3                Plankalkül
# 4    ARC/Birkbeck Assembler
# ..                      ...
# 389            Fortran 2018
# 390                  Bosque
# 391                   C++20
# 392      Microsoft Power Fx
# 393                  Carbon
#
#                               Chief developer, company  \
# 0                                Joseph Marie Jacquard
# 1                                        Gottlob Frege
# 2                                                  IBM
# 3
# 4                                       Kathleen Booth
# ..                                                 ...
# 389                   ISO/IEC JTC1/SC22/WG5 N2150:2018
# 390                             Mark Marron, Microsoft
# 391                             C++ ISO/IEC 14882:2020
# 392  Vijay Mital, Robin Abraham, Shon Katzenberger,...
# 393                                             Google
#
# ...
